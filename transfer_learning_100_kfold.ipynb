# %% [markdown]
# ## Load dataset

# %%
import numpy as np

from keras import backend as K
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from keras import optimizers

seed = 42

np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')

n_training_examples = x_train.shape[0]
n_testing_examples = x_test.shape[0]
print('Training data shape: {}'.format(x_train.shape))
print('Number of training examples: {}'.format(n_training_examples))
print('Number of testing examples: {}'.format(n_testing_examples))
# Out:
# Training data shape: (50000, 32, 32, 3)
# Number of training examples: 50000
# Number of testing examples: 10000

# %% [markdown]
# ## Set hyperparameters

# %%
batch_size = 16
n_epochs = 30
n_classes = 100

# %% [markdown]
# ## Data generator

# %%
from keras.applications.resnet50 import preprocess_input
import cv2

def image_generator(images, labels):
    def generator():
        start = 0
        end = batch_size
        n = len(images)
        while True:
            img_batch_resized = np.array([cv2.resize(img, (224, 224), interpolation=cv2.INTER_CUBIC) for img in images[start:end]])
            img_batch_resized = img_batch_resized.astype('float32')
            img_batch_preprocessed = preprocess_input(img_batch_resized)
            label_batch = labels[start:end]
            
            start += batch_size
            end += batch_size
            if start >= n:
                start = 0
                end = batch_size
            yield (img_batch_preprocessed, label_batch)
    return generator

# %% [markdown]
# ## Pre-trained model

# %%
from keras.applications.resnet50 import ResNet50
pretrained_model = ResNet50(weights='imagenet', include_top=False)

# %% [markdown]
# ## Extract features

# %%
# K-fold cross validation
from sklearn.model_selection import StratifiedKFold

y_train = y_train.flatten()
y_test = y_test.flatten()

X = np.concatenate([x_train, x_test], axis=0)
Y = np.concatenate([y_train, y_test], axis=0)

kfold = StratifiedKFold(n_splits=6, shuffle=True, random_state=seed)
cvscores = []

for train, test in kfold.split(X, Y):
    X_train = X[train]
    X_test = X[test]
    
    # preprocessing
    Y_train = np.eye(n_classes)[Y[train]]
    Y_test = np.eye(n_classes)[Y[test]]
    
    # bottleneck feature extraction
    train_datagen = image_generator(X_train, Y_train)
    bottleneck_features_training = pretrained_model.predict_generator(train_datagen(), len(X_train)//batch_size)

    test_datagen = image_generator(X_test, Y_test)
    bottleneck_features_testing = pretrained_model.predict_generator(test_datagen(), len(X_test)//batch_size)

    # Create model
    model = Sequential()
    model.add(Flatten(input_shape=bottleneck_features_training.shape[1:]))
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(n_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer=optimizers.RMSprop(lr=2e-5), loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Fit model
    history = model.fit(bottleneck_features_training, Y_train, 
          epochs=n_epochs,
          batch_size=batch_size,
          validation_data=(bottleneck_features_testing, Y_test),
          verbose=2)
    
    # Test accuracy
    scores = model.evaluate(bottleneck_features_testing, Y_test, batch_size=batch_size)
    print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1]*100)
    
print("Cross validation scores:")
print(cvscores)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9091 - acc: 0.3098 - val_loss: 1.5304 - val_acc: 0.6132
# Epoch 2/30
#  - 14s - loss: 1.6069 - acc: 0.5527 - val_loss: 1.1838 - val_acc: 0.6710
# Epoch 3/30
#  - 14s - loss: 1.3228 - acc: 0.6213 - val_loss: 1.0640 - val_acc: 0.6950
# Epoch 4/30
#  - 13s - loss: 1.1841 - acc: 0.6560 - val_loss: 0.9984 - val_acc: 0.7076
# Epoch 5/30
#  - 14s - loss: 1.0907 - acc: 0.6819 - val_loss: 0.9534 - val_acc: 0.7173
# Epoch 6/30
#  - 14s - loss: 1.0176 - acc: 0.7004 - val_loss: 0.9258 - val_acc: 0.7241
# Epoch 7/30
#  - 14s - loss: 0.9650 - acc: 0.7187 - val_loss: 0.9026 - val_acc: 0.7317
# Epoch 8/30
#  - 14s - loss: 0.9182 - acc: 0.7292 - val_loss: 0.8850 - val_acc: 0.7357
# Epoch 9/30
#  - 14s - loss: 0.8855 - acc: 0.7366 - val_loss: 0.8691 - val_acc: 0.7367
# Epoch 10/30
#  - 14s - loss: 0.8480 - acc: 0.7474 - val_loss: 0.8608 - val_acc: 0.7432
# Epoch 11/30
#  - 14s - loss: 0.8226 - acc: 0.7548 - val_loss: 0.8462 - val_acc: 0.7478
# Epoch 12/30
#  - 14s - loss: 0.7944 - acc: 0.7642 - val_loss: 0.8423 - val_acc: 0.7498
# Epoch 13/30
#  - 13s - loss: 0.7722 - acc: 0.7703 - val_loss: 0.8354 - val_acc: 0.7519
# Epoch 14/30
#  - 14s - loss: 0.7512 - acc: 0.7769 - val_loss: 0.8265 - val_acc: 0.7548
# Epoch 15/30
#  - 14s - loss: 0.7285 - acc: 0.7827 - val_loss: 0.8243 - val_acc: 0.7559
# Epoch 16/30
#  - 14s - loss: 0.7103 - acc: 0.7897 - val_loss: 0.8241 - val_acc: 0.7574
# Epoch 17/30
#  - 14s - loss: 0.6940 - acc: 0.7933 - val_loss: 0.8185 - val_acc: 0.7593
# Epoch 18/30
#  - 14s - loss: 0.6711 - acc: 0.8001 - val_loss: 0.8178 - val_acc: 0.7568
# Epoch 19/30
#  - 14s - loss: 0.6622 - acc: 0.8038 - val_loss: 0.8159 - val_acc: 0.7610
# Epoch 20/30
#  - 14s - loss: 0.6443 - acc: 0.8092 - val_loss: 0.8131 - val_acc: 0.7621
# Epoch 21/30
#  - 13s - loss: 0.6317 - acc: 0.8109 - val_loss: 0.8077 - val_acc: 0.7639
# Epoch 22/30
#  - 14s - loss: 0.6154 - acc: 0.8172 - val_loss: 0.8124 - val_acc: 0.7611
# Epoch 23/30
#  - 14s - loss: 0.6024 - acc: 0.8200 - val_loss: 0.8101 - val_acc: 0.7646
# Epoch 24/30
#  - 14s - loss: 0.5957 - acc: 0.8238 - val_loss: 0.8127 - val_acc: 0.7647
# Epoch 25/30
#  - 14s - loss: 0.5829 - acc: 0.8270 - val_loss: 0.8094 - val_acc: 0.7664
# Epoch 26/30
#  - 14s - loss: 0.5689 - acc: 0.8308 - val_loss: 0.8051 - val_acc: 0.7667
# Epoch 27/30
#  - 14s - loss: 0.5594 - acc: 0.8349 - val_loss: 0.8069 - val_acc: 0.7682
# Epoch 28/30
#  - 14s - loss: 0.5435 - acc: 0.8388 - val_loss: 0.8063 - val_acc: 0.7691
# Epoch 29/30
#  - 14s - loss: 0.5355 - acc: 0.8403 - val_loss: 0.8154 - val_acc: 0.7690
# Epoch 30/30
#  - 14s - loss: 0.5290 - acc: 0.8434 - val_loss: 0.8085 - val_acc: 0.7709
# 10000/10000 [==============================] - 1s 104us/step
#
# acc: 77.09%
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9050 - acc: 0.3147 - val_loss: 1.5308 - val_acc: 0.6107
# Epoch 2/30
#  - 13s - loss: 1.6019 - acc: 0.5540 - val_loss: 1.2006 - val_acc: 0.6656
# Epoch 3/30
#  - 13s - loss: 1.3173 - acc: 0.6234 - val_loss: 1.0785 - val_acc: 0.6885
# Epoch 4/30
#  - 14s - loss: 1.1791 - acc: 0.6577 - val_loss: 1.0141 - val_acc: 0.7041
# Epoch 5/30
#  - 13s - loss: 1.0798 - acc: 0.6837 - val_loss: 0.9780 - val_acc: 0.7161
# Epoch 6/30
#  - 13s - loss: 1.0083 - acc: 0.7030 - val_loss: 0.9512 - val_acc: 0.7209
# Epoch 7/30
#  - 13s - loss: 0.9551 - acc: 0.7178 - val_loss: 0.9283 - val_acc: 0.7273
# Epoch 8/30
#  - 13s - loss: 0.9106 - acc: 0.7271 - val_loss: 0.9127 - val_acc: 0.7322
# Epoch 9/30
#  - 13s - loss: 0.8754 - acc: 0.7398 - val_loss: 0.9002 - val_acc: 0.7354
# Epoch 10/30
#  - 13s - loss: 0.8399 - acc: 0.7514 - val_loss: 0.8893 - val_acc: 0.7403
# Epoch 11/30
#  - 13s - loss: 0.8144 - acc: 0.7574 - val_loss: 0.8802 - val_acc: 0.7407
# Epoch 12/30
#  - 13s - loss: 0.7881 - acc: 0.7653 - val_loss: 0.8764 - val_acc: 0.7460
# Epoch 13/30
#  - 14s - loss: 0.7664 - acc: 0.7719 - val_loss: 0.8694 - val_acc: 0.7475
# Epoch 14/30
#  - 13s - loss: 0.7387 - acc: 0.7799 - val_loss: 0.8666 - val_acc: 0.7489
# Epoch 15/30
#  - 14s - loss: 0.7184 - acc: 0.7853 - val_loss: 0.8646 - val_acc: 0.7520
# Epoch 16/30
#  - 14s - loss: 0.6990 - acc: 0.7909 - val_loss: 0.8611 - val_acc: 0.7516
# Epoch 17/30
#  - 14s - loss: 0.6860 - acc: 0.7947 - val_loss: 0.8574 - val_acc: 0.7533
# Epoch 18/30
#  - 16s - loss: 0.6706 - acc: 0.7985 - val_loss: 0.8574 - val_acc: 0.7570
# Epoch 19/30
#  - 15s - loss: 0.6514 - acc: 0.8055 - val_loss: 0.8604 - val_acc: 0.7545
# Epoch 20/30
#  - 13s - loss: 0.6370 - acc: 0.8085 - val_loss: 0.8567 - val_acc: 0.7558
# Epoch 21/30
#  - 13s - loss: 0.6220 - acc: 0.8141 - val_loss: 0.8553 - val_acc: 0.7557
# Epoch 22/30
#  - 14s - loss: 0.6097 - acc: 0.8182 - val_loss: 0.8540 - val_acc: 0.7582
# Epoch 23/30
#  - 13s - loss: 0.5975 - acc: 0.8221 - val_loss: 0.8554 - val_acc: 0.7587
# Epoch 24/30
#  - 14s - loss: 0.5831 - acc: 0.8270 - val_loss: 0.8574 - val_acc: 0.7598
# Epoch 25/30
#  - 13s - loss: 0.5705 - acc: 0.8305 - val_loss: 0.8611 - val_acc: 0.7617
# Epoch 26/30
#  - 13s - loss: 0.5611 - acc: 0.8331 - val_loss: 0.8576 - val_acc: 0.7616
# Epoch 27/30
#  - 13s - loss: 0.5478 - acc: 0.8363 - val_loss: 0.8587 - val_acc: 0.7631
# Epoch 28/30
#  - 13s - loss: 0.5411 - acc: 0.8374 - val_loss: 0.8573 - val_acc: 0.7625
# Epoch 29/30
#  - 13s - loss: 0.5310 - acc: 0.8421 - val_loss: 0.8614 - val_acc: 0.7630
# Epoch 30/30
#  - 13s - loss: 0.5196 - acc: 0.8457 - val_loss: 0.8671 - val_acc: 0.7636
# 10000/10000 [==============================] - 1s 113us/step
#
# acc: 76.36%
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9400 - acc: 0.3076 - val_loss: 1.5607 - val_acc: 0.6102
# Epoch 2/30
#  - 14s - loss: 1.6280 - acc: 0.5511 - val_loss: 1.2053 - val_acc: 0.6680
# Epoch 3/30
#  - 13s - loss: 1.3317 - acc: 0.6198 - val_loss: 1.0886 - val_acc: 0.6853
# Epoch 4/30
#  - 13s - loss: 1.1820 - acc: 0.6563 - val_loss: 1.0205 - val_acc: 0.7040
# Epoch 5/30
#  - 14s - loss: 1.0883 - acc: 0.6818 - val_loss: 0.9730 - val_acc: 0.7133
# Epoch 6/30
#  - 13s - loss: 1.0187 - acc: 0.7023 - val_loss: 0.9464 - val_acc: 0.7206
# Epoch 7/30
#  - 14s - loss: 0.9608 - acc: 0.7169 - val_loss: 0.9242 - val_acc: 0.7302
# Epoch 8/30
#  - 14s - loss: 0.9201 - acc: 0.7281 - val_loss: 0.9106 - val_acc: 0.7293
# Epoch 9/30
#  - 14s - loss: 0.8753 - acc: 0.7410 - val_loss: 0.8975 - val_acc: 0.7339
# Epoch 10/30
#  - 14s - loss: 0.8446 - acc: 0.7499 - val_loss: 0.8867 - val_acc: 0.7380
# Epoch 11/30
#  - 13s - loss: 0.8204 - acc: 0.7562 - val_loss: 0.8784 - val_acc: 0.7414
# Epoch 12/30
#  - 13s - loss: 0.7927 - acc: 0.7644 - val_loss: 0.8661 - val_acc: 0.7458
# Epoch 13/30
#  - 13s - loss: 0.7654 - acc: 0.7714 - val_loss: 0.8653 - val_acc: 0.7469
# Epoch 14/30
#  - 13s - loss: 0.7438 - acc: 0.7785 - val_loss: 0.8600 - val_acc: 0.7484
# Epoch 15/30
#  - 13s - loss: 0.7270 - acc: 0.7833 - val_loss: 0.8586 - val_acc: 0.7509
# Epoch 16/30
#  - 14s - loss: 0.7083 - acc: 0.7901 - val_loss: 0.8529 - val_acc: 0.7519
# Epoch 17/30
#  - 13s - loss: 0.6859 - acc: 0.7972 - val_loss: 0.8498 - val_acc: 0.7518
# Epoch 18/30
#  - 14s - loss: 0.6718 - acc: 0.8007 - val_loss: 0.8507 - val_acc: 0.7536
# Epoch 19/30
#  - 13s - loss: 0.6588 - acc: 0.8045 - val_loss: 0.8493 - val_acc: 0.7553
# Epoch 20/30
#  - 13s - loss: 0.6410 - acc: 0.8086 - val_loss: 0.8446 - val_acc: 0.7562
# Epoch 21/30
#  - 13s - loss: 0.6252 - acc: 0.8140 - val_loss: 0.8459 - val_acc: 0.7566
# Epoch 22/30
#  - 13s - loss: 0.6155 - acc: 0.8162 - val_loss: 0.8475 - val_acc: 0.7590
# Epoch 23/30
#  - 13s - loss: 0.6000 - acc: 0.8203 - val_loss: 0.8458 - val_acc: 0.7594
# Epoch 24/30
#  - 13s - loss: 0.5891 - acc: 0.8249 - val_loss: 0.8463 - val_acc: 0.7612
# Epoch 25/30
#  - 13s - loss: 0.5797 - acc: 0.8279 - val_loss: 0.8438 - val_acc: 0.7595
# Epoch 26/30
#  - 13s - loss: 0.5651 - acc: 0.8313 - val_loss: 0.8475 - val_acc: 0.7608
# Epoch 27/30
#  - 13s - loss: 0.5613 - acc: 0.8337 - val_loss: 0.8459 - val_acc: 0.7635
# Epoch 28/30
#  - 13s - loss: 0.5436 - acc: 0.8387 - val_loss: 0.8520 - val_acc: 0.7624
# Epoch 29/30
#  - 13s - loss: 0.5347 - acc: 0.8424 - val_loss: 0.8483 - val_acc: 0.7647
# Epoch 30/30
#  - 13s - loss: 0.5238 - acc: 0.8436 - val_loss: 0.8525 - val_acc: 0.7640
# 10000/10000 [==============================] - 1s 107us/step
#
# acc: 76.40%
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9062 - acc: 0.3149 - val_loss: 1.5393 - val_acc: 0.6053
# Epoch 2/30
#  - 14s - loss: 1.6077 - acc: 0.5568 - val_loss: 1.1876 - val_acc: 0.6664
# Epoch 3/30
#  - 13s - loss: 1.3212 - acc: 0.6242 - val_loss: 1.0663 - val_acc: 0.6943
# Epoch 4/30
#  - 13s - loss: 1.1777 - acc: 0.6597 - val_loss: 1.0022 - val_acc: 0.7075
# Epoch 5/30
#  - 13s - loss: 1.0858 - acc: 0.6849 - val_loss: 0.9602 - val_acc: 0.7139
# Epoch 6/30
#  - 13s - loss: 1.0160 - acc: 0.7015 - val_loss: 0.9318 - val_acc: 0.7232
# Epoch 7/30
#  - 13s - loss: 0.9598 - acc: 0.7186 - val_loss: 0.9084 - val_acc: 0.7295
# Epoch 8/30
#  - 13s - loss: 0.9155 - acc: 0.7309 - val_loss: 0.8911 - val_acc: 0.7316
# Epoch 9/30
#  - 13s - loss: 0.8795 - acc: 0.7409 - val_loss: 0.8813 - val_acc: 0.7363
# Epoch 10/30
#  - 13s - loss: 0.8489 - acc: 0.7512 - val_loss: 0.8679 - val_acc: 0.7392
# Epoch 11/30
#  - 13s - loss: 0.8143 - acc: 0.7589 - val_loss: 0.8600 - val_acc: 0.7428
# Epoch 12/30
#  - 13s - loss: 0.7958 - acc: 0.7666 - val_loss: 0.8571 - val_acc: 0.7451
# Epoch 13/30
#  - 13s - loss: 0.7710 - acc: 0.7726 - val_loss: 0.8495 - val_acc: 0.7465
# Epoch 14/30
#  - 13s - loss: 0.7451 - acc: 0.7801 - val_loss: 0.8410 - val_acc: 0.7485
# Epoch 15/30
#  - 13s - loss: 0.7241 - acc: 0.7847 - val_loss: 0.8377 - val_acc: 0.7513
# Epoch 16/30
#  - 13s - loss: 0.7072 - acc: 0.7910 - val_loss: 0.8392 - val_acc: 0.7520
# Epoch 17/30
#  - 13s - loss: 0.6901 - acc: 0.7953 - val_loss: 0.8365 - val_acc: 0.7514
# Epoch 18/30
#  - 13s - loss: 0.6749 - acc: 0.7986 - val_loss: 0.8292 - val_acc: 0.7533
# Epoch 19/30
#  - 13s - loss: 0.6529 - acc: 0.8059 - val_loss: 0.8292 - val_acc: 0.7559
# Epoch 20/30
#  - 13s - loss: 0.6418 - acc: 0.8080 - val_loss: 0.8293 - val_acc: 0.7524
# Epoch 21/30
#  - 13s - loss: 0.6264 - acc: 0.8128 - val_loss: 0.8265 - val_acc: 0.7592
# Epoch 22/30
#  - 13s - loss: 0.6137 - acc: 0.8163 - val_loss: 0.8292 - val_acc: 0.7586
# Epoch 23/30
#  - 13s - loss: 0.6062 - acc: 0.8203 - val_loss: 0.8263 - val_acc: 0.7593
# Epoch 24/30
#  - 13s - loss: 0.5898 - acc: 0.8248 - val_loss: 0.8295 - val_acc: 0.7607
# Epoch 25/30
#  - 13s - loss: 0.5732 - acc: 0.8291 - val_loss: 0.8250 - val_acc: 0.7612
# Epoch 26/30
#  - 13s - loss: 0.5669 - acc: 0.8306 - val_loss: 0.8292 - val_acc: 0.7609
# Epoch 27/30
#  - 14s - loss: 0.5564 - acc: 0.8352 - val_loss: 0.8338 - val_acc: 0.7628
# Epoch 28/30
#  - 13s - loss: 0.5441 - acc: 0.8376 - val_loss: 0.8353 - val_acc: 0.7604
# Epoch 29/30
#  - 13s - loss: 0.5349 - acc: 0.8401 - val_loss: 0.8366 - val_acc: 0.7623
# Epoch 30/30
#  - 14s - loss: 0.5267 - acc: 0.8452 - val_loss: 0.8376 - val_acc: 0.7636
# 10000/10000 [==============================] - 1s 91us/step
#
# acc: 76.36%
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9055 - acc: 0.3151 - val_loss: 1.5626 - val_acc: 0.5988
# Epoch 2/30
#  - 14s - loss: 1.6052 - acc: 0.5572 - val_loss: 1.2098 - val_acc: 0.6613
# Epoch 3/30
#  - 13s - loss: 1.3144 - acc: 0.6226 - val_loss: 1.0891 - val_acc: 0.6832
# Epoch 4/30
#  - 13s - loss: 1.1798 - acc: 0.6584 - val_loss: 1.0215 - val_acc: 0.6991
# Epoch 5/30
#  - 13s - loss: 1.0851 - acc: 0.6821 - val_loss: 0.9793 - val_acc: 0.7134
# Epoch 6/30
#  - 13s - loss: 1.0103 - acc: 0.7040 - val_loss: 0.9518 - val_acc: 0.7182
# Epoch 7/30
#  - 13s - loss: 0.9606 - acc: 0.7170 - val_loss: 0.9292 - val_acc: 0.7243
# Epoch 8/30
#  - 14s - loss: 0.9126 - acc: 0.7290 - val_loss: 0.9131 - val_acc: 0.7295
# Epoch 9/30
#  - 13s - loss: 0.8782 - acc: 0.7404 - val_loss: 0.8983 - val_acc: 0.7340
# Epoch 10/30
#  - 13s - loss: 0.8449 - acc: 0.7511 - val_loss: 0.8882 - val_acc: 0.7358
# Epoch 11/30
#  - 13s - loss: 0.8126 - acc: 0.7593 - val_loss: 0.8791 - val_acc: 0.7406
# Epoch 12/30
#  - 13s - loss: 0.7905 - acc: 0.7659 - val_loss: 0.8712 - val_acc: 0.7432
# Epoch 13/30
#  - 13s - loss: 0.7669 - acc: 0.7704 - val_loss: 0.8688 - val_acc: 0.7466
# Epoch 14/30
#  - 13s - loss: 0.7444 - acc: 0.7776 - val_loss: 0.8639 - val_acc: 0.7460
# Epoch 15/30
#  - 13s - loss: 0.7238 - acc: 0.7851 - val_loss: 0.8604 - val_acc: 0.7489
# Epoch 16/30
#  - 13s - loss: 0.7046 - acc: 0.7901 - val_loss: 0.8567 - val_acc: 0.7516
# Epoch 17/30
#  - 14s - loss: 0.6933 - acc: 0.7928 - val_loss: 0.8532 - val_acc: 0.7528
# Epoch 18/30
#  - 13s - loss: 0.6711 - acc: 0.8012 - val_loss: 0.8482 - val_acc: 0.7539
# Epoch 19/30
#  - 13s - loss: 0.6572 - acc: 0.8041 - val_loss: 0.8500 - val_acc: 0.7559
# Epoch 20/30
#  - 13s - loss: 0.6426 - acc: 0.8094 - val_loss: 0.8481 - val_acc: 0.7574
# Epoch 21/30
#  - 13s - loss: 0.6242 - acc: 0.8146 - val_loss: 0.8486 - val_acc: 0.7572
# Epoch 22/30
#  - 13s - loss: 0.6132 - acc: 0.8181 - val_loss: 0.8449 - val_acc: 0.7582
# Epoch 23/30
#  - 13s - loss: 0.5991 - acc: 0.8226 - val_loss: 0.8495 - val_acc: 0.7584
# Epoch 24/30
#  - 13s - loss: 0.5852 - acc: 0.8248 - val_loss: 0.8488 - val_acc: 0.7596
# Epoch 25/30
#  - 13s - loss: 0.5775 - acc: 0.8281 - val_loss: 0.8476 - val_acc: 0.7622
# Epoch 26/30
#  - 13s - loss: 0.5635 - acc: 0.8338 - val_loss: 0.8455 - val_acc: 0.7621
# Epoch 27/30
#  - 13s - loss: 0.5541 - acc: 0.8352 - val_loss: 0.8522 - val_acc: 0.7631
# Epoch 28/30
#  - 13s - loss: 0.5451 - acc: 0.8388 - val_loss: 0.8528 - val_acc: 0.7627
# Epoch 29/30
#  - 13s - loss: 0.5330 - acc: 0.8436 - val_loss: 0.8537 - val_acc: 0.7634
# Epoch 30/30
#  - 13s - loss: 0.5232 - acc: 0.8443 - val_loss: 0.8501 - val_acc: 0.7632
# 10000/10000 [==============================] - 1s 95us/step
#
# acc: 76.32%
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#  - 14s - loss: 2.9279 - acc: 0.3150 - val_loss: 1.5107 - val_acc: 0.6176
# Epoch 2/30
#  - 13s - loss: 1.6256 - acc: 0.5525 - val_loss: 1.1547 - val_acc: 0.6789
# Epoch 3/30
#  - 13s - loss: 1.3338 - acc: 0.6209 - val_loss: 1.0355 - val_acc: 0.6984
# Epoch 4/30
#  - 13s - loss: 1.1876 - acc: 0.6560 - val_loss: 0.9689 - val_acc: 0.7140
# Epoch 5/30
#  - 13s - loss: 1.0904 - acc: 0.6830 - val_loss: 0.9260 - val_acc: 0.7240
# Epoch 6/30
#  - 13s - loss: 1.0220 - acc: 0.6990 - val_loss: 0.8961 - val_acc: 0.7331
# Epoch 7/30
#  - 13s - loss: 0.9672 - acc: 0.7162 - val_loss: 0.8764 - val_acc: 0.7377
# Epoch 8/30
#  - 13s - loss: 0.9230 - acc: 0.7291 - val_loss: 0.8634 - val_acc: 0.7428
# Epoch 9/30
#  - 13s - loss: 0.8876 - acc: 0.7385 - val_loss: 0.8513 - val_acc: 0.7468
# Epoch 10/30
#  - 13s - loss: 0.8495 - acc: 0.7493 - val_loss: 0.8401 - val_acc: 0.7498
# Epoch 11/30
#  - 13s - loss: 0.8212 - acc: 0.7575 - val_loss: 0.8312 - val_acc: 0.7538
# Epoch 12/30
#  - 13s - loss: 0.7959 - acc: 0.7627 - val_loss: 0.8236 - val_acc: 0.7553
# Epoch 13/30
#  - 13s - loss: 0.7765 - acc: 0.7710 - val_loss: 0.8214 - val_acc: 0.7572
# Epoch 14/30
#  - 13s - loss: 0.7514 - acc: 0.7774 - val_loss: 0.8174 - val_acc: 0.7592
# Epoch 15/30
#  - 13s - loss: 0.7314 - acc: 0.7824 - val_loss: 0.8141 - val_acc: 0.7614
# Epoch 16/30
#  - 13s - loss: 0.7102 - acc: 0.7892 - val_loss: 0.8131 - val_acc: 0.7622
# Epoch 17/30
#  - 13s - loss: 0.6908 - acc: 0.7968 - val_loss: 0.8103 - val_acc: 0.7647
# Epoch 18/30
#  - 13s - loss: 0.6797 - acc: 0.7983 - val_loss: 0.8076 - val_acc: 0.7647
# Epoch 19/30
#  - 13s - loss: 0.6628 - acc: 0.8024 - val_loss: 0.8029 - val_acc: 0.7656
# Epoch 20/30
#  - 13s - loss: 0.6449 - acc: 0.8100 - val_loss: 0.8052 - val_acc: 0.7701
# Epoch 21/30
#  - 13s - loss: 0.6313 - acc: 0.8134 - val_loss: 0.8013 - val_acc: 0.7687
# Epoch 22/30
#  - 13s - loss: 0.6194 - acc: 0.8160 - val_loss: 0.8012 - val_acc: 0.7694
# Epoch 23/30
#  - 13s - loss: 0.6086 - acc: 0.8202 - val_loss: 0.8006 - val_acc: 0.7713
# Epoch 24/30
#  - 13s - loss: 0.5947 - acc: 0.8252 - val_loss: 0.8034 - val_acc: 0.7717
# Epoch 25/30
#  - 13s - loss: 0.5814 - acc: 0.8277 - val_loss: 0.8023 - val_acc: 0.7717
# Epoch 26/30
#  - 13s - loss: 0.5700 - acc: 0.8313 - val_loss: 0.7995 - val_acc: 0.7733
# Epoch 27/30
#  - 13s - loss: 0.5624 - acc: 0.8329 - val_loss: 0.8011 - val_acc: 0.7735
# Epoch 28/30
#  - 13s - loss: 0.5466 - acc: 0.8394 - val_loss: 0.8022 - val_acc: 0.7720
# Epoch 29/30
#  - 13s - loss: 0.5388 - acc: 0.8401 - val_loss: 0.8034 - val_acc: 0.7763
# Epoch 30/30
#  - 13s - loss: 0.5291 - acc: 0.8430 - val_loss: 0.8040 - val_acc: 0.7754
# 10000/10000 [==============================] - 1s 93us/step
#
# acc: 77.54%
# Cross validation scores:
# [77.090000000000003, 76.359999999999999, 76.400000000000006, 76.359999999999999, 76.319999999999993, 77.539999999999992]
# 76.68% (+/- 0.47%)

# %% [markdown]
# References
# - https://keras.io/applications/
# - The Keras Blog https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
# - http://nbviewer.jupyter.org/github/fchollet/deep-learning-with-python-notebooks/blob/master/5.3-using-a-pretrained-convnet.ipynb
# - Learn OpenCV https://www.learnopencv.com/keras-tutorial-transfer-learning-using-pre-trained-models/
# - Cifar10 classification experiments https://github.com/rnoxy/cifar10-cnn
